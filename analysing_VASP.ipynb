# %% [markdown]
# # Looking at output of VASP calculations to analyse accuracy of GGA + correction vs HSE optics spectra

# %%
from pymatgen.io.vasp import Vasprun
from vasppy.optics import absorption_coefficient as ac
import numpy as np
import matplotlib.pyplot as plt

# %%
si_gga_bands = Vasprun('gga/Si/bands/vasprun.xml').as_dict()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 si_gga_bands = Vasprun('gga/Si/bands/vasprun.xml').as_dict()
#
# File ~/miniforge3/envs/alignn-env/lib/python3.10/site-packages/pymatgen/io/vasp/outputs.py:265, in Vasprun.__init__(self, filename, ionic_step_skip, ionic_step_offset, parse_dos, parse_eigen, parse_projected_eigen, parse_potcar_file, occu_tol, separate_spins, exception_on_bad_xml)
#     262 self.separate_spins = separate_spins
#     263 self.exception_on_bad_xml = exception_on_bad_xml
# --> 265 with zopen(filename, "rt") as f:
#     266     if ionic_step_skip or ionic_step_offset:
#     267         # remove parts of the xml file and parse the string
#     268         run = f.read()
#
# File ~/miniforge3/envs/alignn-env/lib/python3.10/site-packages/monty/io.py:45, in zopen(filename, *args, **kwargs)
#      43 if ext in (".XZ", ".LZMA"):
#      44     return lzma.open(filename, *args, **kwargs)
# ---> 45 return open(filename, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'gga/Si/bands/vasprun.xml'
